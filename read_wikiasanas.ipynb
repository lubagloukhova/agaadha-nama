# %%
import pandas as pd
import re

# %%
df = pd.read_csv('/home/lvg/wiki-table-scrape/wikiasanas/wikiasanas.csv')
print df.shape
df.head()
# Out:
# (253, 5)
#   International Alphabet of Sanskrit Transliteration                Sanskrit  \
# 0                               Adho Mukha Śvānāsana          अधोमुखश्वानासन
# 1                               Adho Mukha Vṛkṣāsana          अधोमुखवृक्षासन
# 2                                 Ākarṇa Dhanurāsana            आकर्णधनुरासन
# 3                              Baddha Vīrabhadrāsana          बद्धवीरभद्रासन
# 4                    Ardha Baddha Parivṛtta Mālāsana  अर्धबद्धपरिवृत्तमालासन
#
#                             English                           Classification  \
# 0          Downward-Facing Dog Pose             Arm balance and Forward Bend
# 1              Downward-Facing Tree                         Full Arm balance
# 2             Bow posture up to ear  Forward Bend (Pashchima Pratana Sthiti)
# 3                Bound Warrior Pose          Backbend (Purva Pratana Sthiti)
# 4  Half Bound Revolved Garland Pose              Twisting (Parivrtta Sthiti)
#
#    Image
# 0    NaN
# ...

# %%
# remove accents
# https://stackoverflow.com/questions/50253753/how-to-replace-accents-in-a-column-of-a-pandas-dataframe
for form in  ['NFC', 'NFKC', 'NFD', 'NFKD']:
    print form 
    sub = df['International Alphabet of Sanskrit Transliteration'].str\
        .normalize(form).str\
        .encode('ascii', errors='ignore').str\
        .decode('utf-8').iloc[0:9].tolist()
    print sub
    print
# Out:
# NFC
# [u'Adho Mukha vnsana', u'Adho Mukha Vksana', u'kara Dhanursana', u'Baddha Vrabhadrsana', u'Ardha Baddha Parivtta Mlsana', u'Ardha Baddha Nantum Naarjsana', u'Ardha Baddha Nirlamba Baddha Eka Pda Uttnsana', u'Ardha Padma Eka Pda Mlsana', u'nanda Blsana']
#
# NFKC
# [u'Adho Mukha vnsana', u'Adho Mukha V1k1sana', u'kar1a Dhanursana', u'Baddha Vrabhadrsana', u'Ardha Baddha Pariv1tta Mlsana', u'Ardha Baddha Nantum Na1arjsana', u'Ardha Baddha Nirlamba Baddha Eka Pda Uttnsana', u'Ardha Padma Eka Pda Mlsana', u'nanda Blsana']
#
# NFD
# [u'Adho Mukha AvAnAsana', u'Adho Mukha VakaAsana', u'Akaraa DhanurAsana', u'Baddha VArabhadrAsana', u'Ardha Baddha Parivatta MAlAsana', u'Ardha Baddha Nantum NaaarAjAsana', u'Ardha Baddha NirAlamba Baddha Eka PAda UttAnAsana', u'Ardha Padma Eka PAda MAlAsana', u'Ananda BAlAsana']
#
# NFKD
# ...

# %%
df['International Alphabet of Sanskrit Transliteration'][0:9]
# Out:
# 0                                 Adho Mukha Śvānāsana
# 1                                 Adho Mukha Vṛkṣāsana
# 2                                   Ākarṇa Dhanurāsana
# 3                                Baddha Vīrabhadrāsana
# 4                      Ardha Baddha Parivṛtta Mālāsana
# 5                     Ardha Baddha Nantum Naṭarājāsana
# 6    Ardha Baddha Nirālamba Baddha Eka Pāda Uttānāsana
# 7                        Ardha Padma Eka Pāda Mālāsana
# 8                                      Ānanda Bālāsana
# Name: International Alphabet of Sanskrit Transliteration, dtype: object

# %%
# https://stackoverflow.com/questions/517923/what-is-the-best-way-to-remove-accents-in-a-python-unicode-string
import unidecode
[unidecode.unidecode(x) for x in df['International Alphabet of Sanskrit Transliteration'][0:9]]
# Out:
# /usr/local/lib/python2.7/dist-packages/unidecode/__init__.py:46: RuntimeWarning: Argument <type 'str'> is not an unicode object. Passing an encoded string will likely have unexpected results.
#   _warn_if_not_unicode(string)
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-24-96077feb1ac4> in <module>()
#       1 # https://stackoverflow.com/questions/517923/what-is-the-best-way-to-remove-accents-in-a-python-unicode-string
#       2 import unidecode
# ----> 3 [unidecode.unidecode(x) for x in df['International Alphabet of Sanskrit Transliteration'][0:9]]
#
# /usr/local/lib/python2.7/dist-packages/unidecode/__init__.pyc in unidecode_expect_ascii(string)
#      46     _warn_if_not_unicode(string)
#      47     try:
# ---> 48         bytestring = string.encode('ASCII')
#      49     except UnicodeEncodeError:
#      50         return _unidecode(string)
#
# ...

# %%
from StringIO import StringIO
s = StringIO(u"""\
English	Sanskrit
Bharadvaja’s Twist	Bharadvajasana I
Big Toe Pose	Padangusthasana
Boat Pose	Paripurna Navasana
Bound Angle Pose	Baddha Konasana
Bow Pose	Dhanurasana
Bridge Pose	Setu Bandha Sarvangasana
Camel Pose	Ustrasana
Cat Pose	Marjaryasana
Chair Pose	Utkatasana
Child’s Pose	Balasana
Cobra Pose	Bhujangasana
Corpse Pose	Savasana
Cow Face Pose	Gomukhasana
Cow Pose	Bitilasana
Crane (Crow) Pose	Bakasana
Downward-Facing Dog	Adho Mukha Svanasana
Eagle Pose	Garudasana
Easy Pose	Sukhasana
Eight-Angle Pose	Astavakrasana
Extended Hand-To-Big-Toe Pose	Utthita Hasta Padangustasana
Extended Puppy Pose	Uttana Shishosana
Extended Side Angle Pose	Utthita Parsvakonasana
Extended Triangle Pose	Utthita Trikonasana
Feathered Peacock Pose	Pincha Mayurasana
Fire Log Pose	Agnistambhasana
Firefly Pose	Tittibhasana
Fish Pose	Matsyasana
Four-Limbed Staff Pose	Chaturanga Dandasana
Garland Pose	Malasana
Gate Pose	Parighasana
Half Frog Pose	Ardha Bhekasana
Half Lord of the Fishes Pose	Ardha Matsyendrasana
Half Moon Pose	Ardha Chandrasana
Handstand	Adho Mukha Vrksasana
Happy Baby Pose	Ananda Balasana
Head-to-Knee Forward Bend	Janu Sirsasana
Hero Pose	Virasana
Heron Pose	Krounchasana
Intense Side Stretch Pose	Parsvottanasana
Legs-Up-the-Wall Pose	Viparita Karani
Locust Pose	Salabhasana
Lord of the Dance Pose	Natarajasana
Lotus Pose	Padmasana
Low Lunge	Anjaneyasana
Marichi’s Pose	Marichyasana III
Monkey Pose	Hanumanasana
Mountain Pose	Tadasana
Noose Pose	Pasasana
One-Legged King Pigeon Pose	Eka Pada Rajakapotasana
One-Legged King Pigeon Pose II	Eka Pada Rajakapotasana II
Peacock Pose	Mayurasana
Pigeon Pose	Kapotasana
Plow Pose	Halasana
Pose Dedicated to the Sage Koundinya I	Eka Pada Koundinyanasana I
Pose Dedicated to the Sage Koundinya II	Eka Pada Koundinyanasana II
Pose Dedicated to the Sage Marichi I	Marichyasana I
Reclining Bound Angle Pose	Supta Baddha Konasana
Reclining Hand-to-Big-Toe Pose	Supta Padangusthasana
Reclining Hero Pose	Supta Virasana
Revolved Head-to-Knee Pose	Parivrtta Janu Sirsasana
Revolved Side Angle Pose	Parivrtta Parsvakonasana
Revolved Triangle Pose	Parivrtta Trikonasana
Scale Pose	Tolasana
Seated Forward Bend	Paschimottanasana
Shoulder-Pressing Pose	Bhujapidasana
Side Crane (Crow) Pose	Parsva Bakasana
Side Plank Pose	Vasisthasana
Side-Reclining Leg Lift	Anantasana
Staff Pose	Dandasana
Standing Forward Bend	Uttanasana
Standing Half Forward Bend	Ardha Uttanasana
Standing Split	Urdhva Prasarita Eka Padasana
Supported Headstand	Salamba Sirsasana
Supported Shoulderstand	Salamba Sarvangasana
Tree Pose	Vrksasana
