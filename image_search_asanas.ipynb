# %%
# image_search google cat --limit 10 --json

# %%
import pandas as pd
import os
from StringIO import StringIO

# %%
done_df = pd.read_fwf(StringIO(u"""\
drwxrwxr-x 2 lvg lvg 32768 Jul 30 18:22 Vrschikasana
drwxrwxr-x 2 lvg lvg 28672 Jul 30 18:19 Viparita+Virabhadrasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 18:16 Utthita+Hasta+Padangusthasana
drwxrwxr-x 2 lvg lvg 20480 Jul 30 18:11 Utthan+Pristhasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 18:08 Trikonasana
drwxrwxr-x 2 lvg lvg 40960 Jul 30 18:02 Triang+Mukhaikapada+Paschimottanasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 17:54 Svarga+Dvidasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 17:45 Supta+Matsyendrasana
drwxrwxr-x 2 lvg lvg 45056 Jul 30 17:36 Supta+Balasana,
drwxrwxr-x 2 lvg lvg 36864 Jul 30 17:31 Sunbird+Pose
drwxrwxr-x 2 lvg lvg 36864 Jul 30 17:26 Sukasana
drwxrwxr-x 2 lvg lvg 40960 Jul 30 17:18 Sucirandhrasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:59 Sphinx+Pose
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:53 Sasangasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:44 Samasthiti
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:36 Salambhasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:29 Plank+Pose
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:24 Parsvakonasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:19 Parivrtta+Sukhasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:14 Parivrtta+Surya+Yantrasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:10 Parivrtta+Marichyasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:06 Parivrtta+Ardha+Chandrasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 16:00 Navasana
drwxrwxr-x 2 lvg lvg 53248 Jul 30 15:53 Marichyasana+II
drwxrwxr-x 2 lvg lvg 36864 Jul 30 15:47 Laghu+Vajrasana
drwxrwxr-x 2 lvg lvg 32768 Jul 30 15:40 Karnapidasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 15:36 Eka+Pada+Koundiyanasana+II
drwxrwxr-x 2 lvg lvg 36864 Jul 30 15:32 Eka+Pada+Koundiyanasana+I
drwxrwxr-x 2 lvg lvg 32768 Jul 30 15:27 Eka+Pada+Galavasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 15:23 Eka+Hasta+Bhujasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 15:19 Dolphin+Pose
drwxrwxr-x 2 lvg lvg 24576 Jul 30 15:12 Dolphin+Plank+Pose
drwxrwxr-x 2 lvg lvg 36864 Jul 30 15:07 Chakravakasana
drwxrwxr-x 2 lvg lvg 57344 Jul 30 15:03 Catuspadapitham+Pose
drwxrwxr-x 2 lvg lvg 36864 Jul 30 14:57 Bhujapidasana+Pose
drwxrwxr-x 2 lvg lvg 24576 Jul 30 14:53 Bhekasana
drwxrwxr-x 2 lvg lvg 36864 Jul 30 14:49 Bharadvajasana+I+Twist
drwxrwxr-x 2 lvg lvg 32768 Jul 30 14:43 Ardha+Padmasana
drwxrwxr-x 2 lvg lvg 49152 Jul 29 23:03 Supta+Balasana
drwxrwxr-x 2 lvg lvg 61440 Jul 29 22:57 Anahatasana+Pose
drwxrwxr-x 2 lvg lvg  4096 Jul 29 22:49 Abhaya+Hridaya+Mudra
drwxrwxr-x 2 lvg lvg 40960 Jul 29 01:07 Ujjayi+Pranayama
drwxrwxr-x 2 lvg lvg 36864 Jul 29 00
ana
drwxrwxr-x 2 lvg lvg 36864 Jul 28 00:41 Setu+Bandha+Sarvangasana
drwxrwxr-x 2 lvg lvg 57344 Jul 28 00:36 Dhanurasana
drwxrwxr-x 2 lvg lvg 40960 Jul 28 00:27 Baddha+Konasana
drwxrwxr-x 2 lvg lvg 20480 Jul 28 00:21 Paripurna+Navasana
drwxrwxr-x 2 lvg lvg 36864 Jul 28 00:19 Padangusthasana
drwxrwxr-x 2 lvg lvg 36864 Jul 27 23:42 Bharadvajasana+I
"""), header=None)
print done_df.shape
done_df.head()
# Out:
# (100, 9)
#             0  1    2    3      4    5   6      7  \
# 0  drwxrwxr-x  2  lvg  lvg  32768  Jul  30  18:22
# 1  drwxrwxr-x  2  lvg  lvg  28672  Jul  30  18:19
# 2  drwxrwxr-x  2  lvg  lvg  36864  Jul  30  18:16
# 3  drwxrwxr-x  2  lvg  lvg  20480  Jul  30  18:11
# 4  drwxrwxr-x  2  lvg  lvg  36864  Jul  30  18:08
#
#                                8
# 0                   Vrschikasana
# 1        Viparita+Virabhadrasana
# 2  Utthita+Hasta+Padangusthasana
# 3             Utthan+Pristhasana
# 4                    Trikonasana

# %%
done_asanas = [x.replace('+',' ') for x in done_df[8].tolist()]
print (len(done_asanas))
done_asanas
# Out:
# 100
# [u'Vrschikasana',
#  u'Viparita Virabhadrasana',
#  u'Utthita Hasta Padangusthasana',
#  u'Utthan Pristhasana',
#  u'Trikonasana',
#  u'Triang Mukhaikapada Paschimottanasana',
#  u'Svarga Dvidasana',
#  u'Supta Matsyendrasana',
#  u'Supta Balasana,',
#  u'Sunbird Pose',
#  u'Sukasana',
#  u'Sucirandhrasana',
#  u'Sphinx Pose',
#  u'Sasangasana',
#  u'Samasthiti',
#  u'Salambhasana',
#  u'Plank Pose',
#  u'Parsvakonasana',
#  u'Parivrtta Sukhasana',
#  u'Parivrtta Surya Yantrasana',
#  u'Parivrtta Marichyasana',
#  u'Parivrtta Ardha Chandrasana',
#  u'Navasana',
#  u'Marichyasana II',
#  u'Laghu Vajrasana',
#  u'Karnapidasana',
#  u'Eka Pada Koundiyanasana II',
#  u'Eka Pada Koundiyanasana I',
#  u'Eka Pada Galavasana',
#  u'Eka Hasta Bhujasana',
#  u'Dolphin Pose',
#  u'Dolphin Plank Pose',
#  u'Chakravakasana',
#  u'Catuspadapitham Pose',
#  u'Bhujapidasana Pose',
#  u'Bhekasana',
#  u'Bharadvajasana I Twist',
#  u'Ardha Padmasana',
#  u'Supta Balasana',
# ...

# %%
asanas_df = pd.read_csv('asanas.csv')
print asanas_df.shape
asanas_df.head()
# Out:
# (150, 2)
#               English            Sanskrit
# 0  Bharadvaja’s Twist    Bharadvajasana I
# 1        Big Toe Pose     Padangusthasana
# 2           Boat Pose  Paripurna Navasana
# 3    Bound Angle Pose     Baddha Konasana
# 4            Bow Pose         Dhanurasana

# %%
mask = asanas_df['Sanskrit'].isin(done_asanas)
asanas_df = asanas_df[~mask]
print asanas_df.shape
asanas_df.head()
# Out:
# (50, 2)
#                           English                      Sanskrit
# 19  Extended Hand-To-Big-Toe Pose  Utthita Hasta Padangustasana
# 20            Extended Puppy Pose             Uttana Shishosana
# 21       Extended Side Angle Pose        Utthita Parsvakonasana
# 22         Extended Triangle Pose           Utthita Trikonasana
# 23         Feathered Peacock Pose             Pincha Mayurasana

# %%
asanas_df.to_csv('asanas_rem50.csv', index=False)

# %%
pd.read_csv('asanas_rem91.csv')
# Out:
#                              English                               Sanskrit
# 0      Extended Hand-To-Big-Toe Pose           Utthita Hasta Padangustasana
# 1                Extended Puppy Pose                      Uttana Shishosana
# 2           Extended Side Angle Pose                 Utthita Parsvakonasana
# 3             Extended Triangle Pose                    Utthita Trikonasana
# 4             Feathered Peacock Pose                      Pincha Mayurasana
# 5                      Fire Log Pose                        Agnistambhasana
# 6                       Firefly Pose                           Tittibhasana
# 7                          Fish Pose                             Matsyasana
# 8             Four-Limbed Staff Pose                   Chaturanga Dandasana
# 9                       Garland Pose                               Malasana
# 10                         Gate Pose                            Parighasana
# ...

# %%
for asana in asanas_df.Sanskrit[19:]:
    asana = asana.replace(' ','+')
    print asana
    cmd = 'image_search google %s --limit 1000 --json' % asana
#     os.system(cmd)
# Out:
# Utthita+Hasta+Padangustasana
# Uttana+Shishosana
# Utthita+Parsvakonasana
# Utthita+Trikonasana
# Pincha+Mayurasana
# Agnistambhasana
# Tittibhasana
# Matsyasana
# Chaturanga+Dandasana
# Malasana
# Parighasana
# Ardha+Bhekasana
# Ardha+Matsyendrasana
# Ardha+Chandrasana
# Adho+Mukha+Vrksasana
# Ananda+Balasana
# Janu+Sirsasana
# Virasana
# Krounchasana
# Parsvottanasana
# Viparita+Karani
# Salabhasana
# Natarajasana
# Padmasana
# Anjaneyasana
# Marichyasana+III
# Hanumanasana
# Tadasana
# Pasasana
# Eka+Pada+Rajakapotasana
# Eka+Pada+Rajakapotasana+II
# Mayurasana
# Kapotasana
# Halasana
# Eka+Pada+Koundinyanasana+I
# Eka+Pada+Koundinyanasana+II
# Marichyasana+I
# Supta+Baddha+Konasana
# Supta+Padangusthasana
# Supta+Virasana
# Parivrtta+Janu+Sirsasana
# Parivrtta+Parsvakonasana
# Parivrtta+Trikonasana
# Tolasana
# Paschimottanasana
# Bhujapidasana
# Parsva+Bakasana
# Vasisthasana
# Anantasana
# Dandasana
# Uttanasana
# Ardha+Uttanasana
# Urdhva+Prasarita+Eka+Padasana
# ...

# %%
from IPython.display import display, Image, SVG, Math, YouTubeVideo
filename = "dataset/google/Bharadvajasana+I/Scrapper_15.jpg"
i = Image(filename=filename)
i

# %%
os.getcwd()
